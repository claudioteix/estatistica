# %% [markdown]
# <img src="Title.jpg">

# %% [markdown]
# ### ** Estatística Descritiva como parte da Análise Exploratória de Dados**

# %% [markdown]
# ### **Preparações**
#
# Nesta etapa, importa-se as bibliotecas necessárias e carrega-se os arquivos necessários para a análise exploratória dos dados.

# %%
import scipy as sp
import sklearn as skl
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Detailed_Flights_4.txt')
df.head()
# Out:
#   destiny arrival_expect_date arrival_expect_hour origin depart_expect_date  \
# 0    KJFK          01/01/2009            18:00:00   SBGR         01/01/2009
# 1    KJFK          02/01/2009            08:00:00   SBGR         01/01/2009
# 2    KJFK          02/01/2009            09:00:00   SBGL         01/01/2009
# 3    KJFK          02/01/2009            09:00:00   SAEZ         01/01/2009
# 4    KJFK          02/01/2009            09:00:00   SBGR         01/01/2009
#
#   depart_expect_hour airline  flight line_type     depart_expect  \
# 0           08:00:00     TAM    8082         I  01/01/2009 08:45
# 1           22:00:00     TAM    8080         I  01/01/2009 22:30
# 2           23:00:00     TAM    8078         I  01/01/2009 23:15
# 3           22:00:00     AAL     956         I  01/01/2009 22:15
# 4           23:00:00     AAL     950         I  01/01/2009 23:25
#
#           ...         depart_humidity depart_pressure depart_visibility  \
# 0         ...                    83.0          1015.0               NaN
# 1         ...                    94.0          1015.0              10.0
# 2         ...                    83.0          1011.0               NaN
# 3         ...                    59.0          1020.0               NaN
# 4         ...                    94.0          1015.0               NaN
#
#   depart_conditions arrival_temperature  arrival_dew_point  arrival_humidity  \
# 0             Clear                 3.9                9.5              17.2
# 1     Partly Cloudy                 1.7                4.9               8.3
# 2             Clear                 2.2                3.5               8.9
# 3          Overcast                 2.2                3.5               8.9
# 4             Clear                 2.2                3.5               8.9
#
#    arrival_pressure  arrival_visibility  arrival_conditions
# 0              36.0              1025.4                 NaN
# 1              48.0              1016.0                 NaN
# 2              44.0              1015.1                 NaN
# 3              44.0              1015.1                 NaN
# 4              44.0              1015.1                 NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# Visualizando-se de uma forma geral como está estruturado o data set, suas variáveis e tipos de dados.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82822 entries, 0 to 82821
# Data columns (total 34 columns):
# destiny                82822 non-null object
# arrival_expect_date    82822 non-null object
# arrival_expect_hour    82822 non-null object
# origin                 82822 non-null object
# depart_expect_date     82822 non-null object
# depart_expect_hour     82822 non-null object
# airline                82822 non-null object
# flight                 82822 non-null int64
# line_type              82820 non-null object
# depart_expect          82822 non-null object
# depart                 76090 non-null object
# arrival_expect         82822 non-null object
# arrival                76090 non-null object
# status                 82822 non-null object
# observation            22388 non-null object
# departure_delay        76090 non-null float64
# arrival_delay          76090 non-null float64
# duration_expect        82822 non-null int64
# duration               76090 non-null float64
# duration_delta         76090 non-null float64
# origin.state           62344 non-null object
# destiny.state          0 non-null float64
# depart_temperature     82433 non-null float64
# depart_dew_point       81963 non-null float64
# depart_humidity        82445 non-null float64
# depart_pressure        77441 non-null float64
# depart_visibility      54360 non-null float64
# depart_conditions      82822 non-null object
# arrival_temperature    82568 non-null float64
# arrival_dew_point      79043 non-null float64
# arrival_humidity       82565 non-null float64
# arrival_pressure       82614 non-null float64
# arrival_visibility     80196 non-null float64
# arrival_conditions     72809 non-null object
# dtypes: float64(15), int64(2), object(17)
# memory usage: 21.5+ MB

# %% [markdown]
# #### 1. Aplicação de medidas de tendência central, dispersão e correlação entre as variáveis

# %% [markdown]
# **Medidas de Tendência Central**<BR><BR>
# As medidas de tendência central definem valores significativos, representativos e adequados para um conjunto de dados, dependendo do que se deseja analisar. São elas a média, mediana, quartis e a moda.

# %% [markdown]
# **Média**<BR><BR>
# A média é uma medida de tendência central que indica o valor onde estão concentrados os dados de um conjunto de valores, representando um valor significativo para o mesmo. Para o data set em questão, pode-se analisar a média dos atrasos (em minutos) nas partidas e chegadas dos voos.

# %%
df['departure_delay'].mean()
# Out:
# -151.98121960835851

# %%
df['arrival_delay'].mean()
# Out:
# 28.86919351861056

# %% [markdown]
# Observando-se que o resultado da média dos atrasos (em minutos) nas partidas foi um número negativo, pressupõe-se que existem valores negativos para esta variável. Neste caso, pode-se remover esse tipo de inconsistência e calcular novamente a média.

# %%
df = df.query('~(departure_delay < 0)')

# %%
df['departure_delay'].mean()
# Out:
# 21.63934845278839

# %% [markdown]
# Então, tem-se os seguintes resultados:<BR><BR>
# 1.1. Uma média de 21 minutos de atraso nas partidas e;<BR>
# 1.2. Uma média de 28 minutos de atraso nas chegadas

# %% [markdown]
# Segundo a resolução 400 da Agência Nacional de Aviação Civil (ANAC), seja qual for o motivo do atraso no voo, as companhias aéreas são obrigadas a prestar assistência aos passageiros, mesmo que elas não sejam as responsáveis diretas pelo atraso. Determina o artigo 27 desta resolução, o seguinte:<BR>

# %% [markdown]
# A partir de uma hora de atraso: comunicação (internet, telefone, entre outros)<BR>
# A partir de duas horas de atraso: alimentação de acordo com o horário (voucher, refeição, lanche etc)<BR>
# A partir de quatro horas de atraso: hospedagem (somente em caso de pernoite no aeroporto) e transporte de ida e volta. Se o passageiro estiver no local de seu domicílio, a empresa poderá oferecer apenas o transporte para sua residência e de sua casa para o aeroporto.
# <BR>
# Quando o voo atrasar mais de quatro horas ou for cancelado, a companhia aérea deverá oferecer alternativas de reacomodação em outro voo, devolver o valor da passagem ou levar o passageiro por outra modalidade de transporte.

# %% [markdown]
# Para o caso dos resultados encontrados, conclui-se que não incorrerá nos casos previstos da resolução 400 da ANAC.

# %% [markdown]
# **Moda**<BR>
# A moda é o valor que mais se repete dentro de um conjunto.

# %%
df['departure_delay'].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
df['arrival_delay'].mode()
# Out:
# 0    0.0
# dtype: float64

# %% [markdown]
# Quanto as outras medidas, pode-se resumir por meio da função **describe()**.

# %%
df['departure_delay'].describe()
# Out:
# count    70417.000000
# mean        21.639348
# std        241.068862
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      43234.000000
# Name: departure_delay, dtype: float64

# %%
df['arrival_delay'].describe()
# Out:
# count     70417.000000
# mean         28.869194
# std        1995.260727
# min       -1411.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      525660.000000
# Name: arrival_delay, dtype: float64

# %% [markdown]
# Observa-se que a contagem (count = 70417) é menor que o número total de observações (82.822), o que entende-se a existência de valores nulos ou NaN (Not a Number).

# %% [markdown]
# Tem-se também valores negativos para os atrasos nas chegadas e do mesmo modo que removemos essas inconsistências para os valores de atraso nas partidas, executa-se o mesmo procedimento.

# %%
df = df.query('~(arrival_delay < 0)')

# %%
df['departure_delay'].describe()
# Out:
# count    69584.000000
# mean        21.651098
# std        242.488013
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      43234.000000
# Name: departure_delay, dtype: float64

# %%
df['arrival_delay'].describe()
# Out:
# count     69584.000000
# mean         29.618317
# std        2007.144232
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max      525660.000000
# Name: arrival_delay, dtype: float64

# %%
df['duration'].describe()
# Out:
# count    69463.000000
# mean       507.308841
# std        224.920870
# min     -18475.000000
# 25%        490.000000
# 50%        525.000000
# 75%        578.000000
# max       7811.000000
# Name: duration, dtype: float64

# %%
df = df.query('~(duration < 0)')

# %% [markdown]
# Com a remoção das inconsistências, a média dos atrasos nas chegadas ficou em 29 minutos.

# %% [markdown]
# **Medidas de Dispersão**<BR>
# As medidas de dispersão são medidas que indicam o quão espalhados os dados estão, ou como eles variam. São elas a amplitude, a variância, o desvio padrão e o desvio absoluto.

# %% [markdown]
# **Amplitude**<BR>
# A amplitude nada mais é do que a diferença entre o maior e o menor valor de um conjunto de dados.

# %%
max_depart_delay=df['departure_delay'].max()
min_depart_delay=df['departure_delay'].min()
print("Amplitude dos Atrasos nas Partidas = ", max_depart_delay-min_depart_delay)
# Out:
# Amplitude dos Atrasos nas Partidas =  43234.0

# %%
max_arrival_delay=df['arrival_delay'].max()
min_arrival_delay=df['arrival_delay'].min()
print("Amplitude dos Atrasos nas Chegadas = ", max_arrival_delay-min_arrival_delay)
# Out:
# Amplitude dos Atrasos nas Chegadas =  525660.0

# %% [markdown]
# **Variância**<BR>
# A variância é uma medida que expressa quanto os dados de um conjunto estão afastados de seu valor esperado.

# %%
print("Variância dos Atrasos nas Partidas = ", df['departure_delay'].var())
# Out:
# Variância dos Atrasos nas Partidas =  58800.436275361135

# %%
print("Variância dos Atrasos nas Chegadas = ", df['arrival_delay'].var())
# Out:
# Variância dos Atrasos nas Chegadas =  4028627.968813716

# %% [markdown]
# **Desvio Padrão**
# O desvio padrão também é uma medida de dispersão, que indica quanto os dados estão afastados da média. Um valor de desvio padrão alto indica que os valores estão mais espalhados, mais longe da média, e um desvio padrão baixo indica que os valores estão mais próximos da média.
# Nos valores dos atrasos nas Partidas está em 242 minutos e nas Chegadas em 2007 minutos, conforme resultado da função **describe()** acima executado.

# %% [markdown]
# **Desvio absoluto**<BR>
# O Desvio Absoluto é calculado da seguinte forma: primeiro, encontramos a média dos valores; depois, calculamos a distância de cada ponto desta média; somamos as distâncias e dividimos o resultado pela média destas distâncias.

# %%
print("Desvio Absoluto nas Partidas = ",df['departure_delay'].mad())
# Out:
# Desvio Absoluto nas Partidas =  37.56981103048167

# %%
print("Desvio Absoluto nas Chegadas = ",df['arrival_delay'].mad())
# Out:
# Desvio Absoluto nas Chegadas =  51.524281574467075

# %% [markdown]
# **Covariância e Correlação**<BR>
# Em alguns momentos, necessita-se saber se duas variáveis possuem alguma relação entre si dentro de um conjunto de dados. Para estes casos, calculamos a covariância e a correlação.
#
# A covariância é uma medida numérica que indica a inter-dependência entre duas variáveis. A covariância indica como duas variáveis se comportam conjuntamente em relação às suas médias. Uma covariância igual a 0 indica que as duas variáveis são totalmente independentes, enquanto que uma covariância alta e positiva indica que uma variável é grande quando a outra é grande. Analogamente, uma covariância negativa e com valor absoluto alto indica que uma variável é pequena quando a outra é grande.

# %%
print(df.cov())
# Out:
#                            flight  departure_delay  arrival_delay  \
# flight               1.137419e+07    -15717.663474  -16359.088820
# departure_delay     -1.571766e+04     11505.638731    9302.416594
# arrival_delay       -1.635909e+04      9302.416594    9512.917493
# duration_expect      1.226914e+04      1513.515504    -761.155290
# duration             1.162771e+04      -689.706633    -550.654391
# duration_delta      -6.414253e+02     -2203.222137     210.500899
# destiny.state                 NaN              NaN            NaN
# depart_temperature   1.180924e+03       -12.454590     -16.159509
# depart_dew_point     1.374628e+03        -0.614099      -3.926787
# depart_humidity      2.463838e+03        33.051589      31.025673
# depart_pressure      1.274318e+04      -170.026309    -203.917877
# depart_visibility   -1.953791e+04       156.100491     192.970999
# arrival_temperature  1.241862e+03        15.009978      17.928694
# arrival_dew_point    7.532607e+02         6.993702      10.419891
# arrival_humidity    -6.938632e+03        21.321040      28.209197
# arrival_pressure    -4.209192e+04       538.687842     613.896579
# arrival_visibility   3.202933e+04      -593.855872    -683.329335
#
#                      duration_expect      duration  duration_delta  \
# flight                  12269.135583  11627.710237     -641.425346
# departure_delay          1513.515504   -689.706633    -2203.222137
# arrival_delay            -761.155290   -550.654391      210.500899
# duration_expect         17778.134479  15503.463685    -2274.670794
# duration                15503.463685  15642.515927      139.052242
# duration_delta          -2274.670794    139.052242     2413.723036
# destiny.state                    NaN           NaN             NaN
# depart_temperature        -16.624000    -20.328919       -3.704919
# depart_dew_point           -5.664551     -8.977239       -3.312688
# depart_humidity           137.105047    135.079131       -2.025916
# depart_pressure           890.640348    856.748780      -33.891568
# depart_visibility        -935.702578   -898.832070       36.870508
# arrival_temperature      -268.258194   -265.339478        2.918717
# arrival_dew_point        -197.287597   -193.861407        3.426189
# arrival_humidity         -761.512035   -754.623877        6.888157
# arrival_pressure       -10539.516608 -10464.307870       75.208737
# arrival_visibility      11469.826890  11380.353427      -89.473463
#
#                      destiny.state  depart_temperature  depart_dew_point  \
# flight                         NaN         1180.923955       1374.627629
# departure_delay                NaN          -12.454590         -0.614099
# arrival_delay                  NaN          -16.159509         -3.926787
# duration_expect                NaN          -16.624000         -5.664551
# duration                       NaN          -20.328919         -8.977239
# duration_delta                 NaN           -3.704919         -3.312688
# destiny.state                  NaN                 NaN               NaN
# depart_temperature             NaN           24.915835         15.179768
# depart_dew_point               NaN           15.179768         19.651706
# depart_humidity                NaN          -29.511283         19.912196
# depart_pressure                NaN           72.625585          2.882325
# depart_visibility              NaN         -126.106034        -21.784457
# arrival_temperature            NaN           -7.361044         -8.643716
# arrival_dew_point              NaN           -5.755179         -6.862532
# arrival_humidity               NaN           -8.987537        -16.739863
# arrival_pressure               NaN         -154.345185       -237.105485
# arrival_visibility             NaN          183.209825        261.096390
#
#                      depart_humidity  depart_pressure  depart_visibility  \
# flight                   2463.838477     12743.184804      -19537.911520
# departure_delay            33.051589      -170.026309         156.100491
# arrival_delay              31.025673      -203.917877         192.970999
# duration_expect           137.105047       890.640348        -935.702578
# duration                  135.079131       856.748780        -898.832070
# duration_delta             -2.025916       -33.891568          36.870508
# destiny.state                    NaN              NaN                NaN
# depart_temperature        -29.511283        72.625585        -126.106034
# depart_dew_point           19.912196         2.882325         -21.784457
# depart_humidity           269.094172       513.979436        -826.084774
# depart_pressure           513.979436      7079.470530      -10832.254186
# depart_visibility        -826.084774    -10832.254186       11247.364983
# arrival_temperature       -10.335728       -33.853626          63.787625
# arrival_dew_point          -8.715914       -26.226188          52.229954
# arrival_humidity          -40.718687       -50.669914          98.388980
# arrival_pressure         -465.790520      -817.664643        1461.299529
# arrival_visibility        465.496819       920.858233       -1659.627035
#
#                      arrival_temperature  arrival_dew_point  arrival_humidity  \
# flight                       1241.861688         753.260721      -6938.632016
# departure_delay                15.009978           6.993702         21.321040
# arrival_delay                  17.928694          10.419891         28.209197
# duration_expect              -268.258194        -197.287597       -761.512035
# duration                     -265.339478        -193.861407       -754.623877
# duration_delta                  2.918717           3.426189          6.888157
# destiny.state                        NaN                NaN               NaN
# depart_temperature             -7.361044          -5.755179         -8.987537
# depart_dew_point               -8.643716          -6.862532        -16.739863
# depart_humidity               -10.335728          -8.715914        -40.718687
# depart_pressure               -33.853626         -26.226188        -50.669914
# depart_visibility              63.787625          52.229954         98.388980
# arrival_temperature            56.597645          43.016631        136.855988
# arrival_dew_point              43.016631          45.251372        114.824053
# arrival_humidity              136.855988         114.824053        731.566756
# arrival_pressure             1923.102590        1112.427872       7976.065685
# arrival_visibility          -2094.185842       -1229.577018      -8659.234119
#
#                      arrival_pressure  arrival_visibility
# flight                  -42091.922325        32029.331041
# departure_delay            538.687842         -593.855872
# arrival_delay              613.896579         -683.329335
# duration_expect         -10539.516608        11469.826890
# duration                -10464.307870        11380.353427
# duration_delta              75.208737          -89.473463
# destiny.state                     NaN                 NaN
# depart_temperature        -154.345185          183.209825
# depart_dew_point          -237.105485          261.096390
# depart_humidity           -465.790520          465.496819
# depart_pressure           -817.664643          920.858233
# depart_visibility         1461.299529        -1659.627035
# arrival_temperature       1923.102590        -2094.185842
# arrival_dew_point         1112.427872        -1229.577018
# arrival_humidity          7976.065685        -8659.234119
# arrival_pressure        110946.124377      -119601.374739
# arrival_visibility     -119601.374739       125725.629284

# %% [markdown]
# A covariância, entretanto, pode ser difícil de ser compreendida e comparada, pois ela nos dá valores em escalas que serão diferentes conforme as variáveis mudem. Para uma melhor comparação, normalizamos a covariância para ter um valor que sempre estará entre 1 e -1, que é a correlação. Logo, a correlação também é outra medida que indica o quanto duas variáveis estão relacionadas. Seu valor fica sempre entre -1, que indica uma anti-correlação perfeita, e 1, que indica uma correlação perfeita.

# %%
print(df.corr())
# Out:
#                        flight  departure_delay  arrival_delay  \
# flight               1.000000        -0.043448      -0.049733
# departure_delay     -0.043448         1.000000       0.889167
# arrival_delay       -0.049733         0.889167       1.000000
# duration_expect      0.027284         0.105825      -0.058529
# duration             0.027566        -0.051411      -0.045141
# duration_delta      -0.003871        -0.418080       0.043929
# destiny.state             NaN              NaN            NaN
# depart_temperature   0.070188        -0.023237      -0.033169
# depart_dew_point     0.091813        -0.001294      -0.009119
# depart_humidity      0.044555         0.018769       0.019384
# depart_pressure      0.044918        -0.019089      -0.025479
# depart_visibility   -0.052415         0.012316       0.017271
# arrival_temperature  0.048940         0.018607       0.024459
# arrival_dew_point    0.033313         0.009512       0.015613
# arrival_humidity    -0.076056         0.007352       0.010704
# arrival_pressure    -0.037467         0.015086       0.018920
# arrival_visibility   0.026680        -0.015420      -0.019531
#
#                      duration_expect  duration  duration_delta  destiny.state  \
# flight                      0.027284  0.027566       -0.003871            NaN
# departure_delay             0.105825 -0.051411       -0.418080            NaN
# arrival_delay              -0.058529 -0.045141        0.043929            NaN
# duration_expect             1.000000  0.929678       -0.347242            NaN
# duration                    0.929678  1.000000        0.022630            NaN
# duration_delta             -0.347242  0.022630        1.000000            NaN
# destiny.state                    NaN       NaN             NaN            NaN
# depart_temperature         -0.025001 -0.032601       -0.015085            NaN
# depart_dew_point           -0.009618 -0.016258       -0.015168            NaN
# depart_humidity             0.062675  0.065835       -0.002510            NaN
# depart_pressure             0.082685  0.085390       -0.008040            NaN
# depart_visibility          -0.060522 -0.063286        0.005807            NaN
# arrival_temperature        -0.267221 -0.281787        0.007889            NaN
# arrival_dew_point          -0.224191 -0.236312        0.010137            NaN
# arrival_humidity           -0.210991 -0.222904        0.005178            NaN
# arrival_pressure           -0.237170 -0.251043        0.004592            NaN
# arrival_visibility          0.239495  0.253446       -0.005055            NaN
#
#                      depart_temperature  depart_dew_point  depart_humidity  \
# flight                         0.070188          0.091813         0.044555
# departure_delay               -0.023237         -0.001294         0.018769
# arrival_delay                 -0.033169         -0.009119         0.019384
# duration_expect               -0.025001         -0.009618         0.062675
# duration                      -0.032601         -0.016258         0.065835
# duration_delta                -0.015085         -0.015168        -0.002510
# destiny.state                       NaN               NaN              NaN
# depart_temperature             1.000000          0.696901        -0.360568
# depart_dew_point               0.696901          1.000000         0.290071
# depart_humidity               -0.360568          0.290071         1.000000
# depart_pressure                0.174128          0.017135         0.372490
# depart_visibility             -0.229714         -0.121079        -0.491331
# arrival_temperature           -0.195865         -0.258954        -0.083683
# arrival_dew_point             -0.169880         -0.228400        -0.078457
# arrival_humidity              -0.066508         -0.139276        -0.091696
# arrival_pressure              -0.092739         -0.160122        -0.085165
# arrival_visibility             0.103309          0.167167         0.080896
#
#                      depart_pressure  depart_visibility  arrival_temperature  \
# flight                      0.044918          -0.052415             0.048940
# departure_delay            -0.019089           0.012316             0.018607
# arrival_delay              -0.025479           0.017271             0.024459
# duration_expect             0.082685          -0.060522            -0.267221
# duration                    0.085390          -0.063286            -0.281787
# duration_delta             -0.008040           0.005807             0.007889
# destiny.state                    NaN                NaN                  NaN
# depart_temperature          0.174128          -0.229714            -0.195865
# depart_dew_point            0.017135          -0.121079            -0.258954
# depart_humidity             0.372490          -0.491331            -0.083683
# depart_pressure             1.000000          -0.968452            -0.053071
# depart_visibility          -0.968452           1.000000             0.079893
# arrival_temperature        -0.053071           0.079893             1.000000
# arrival_dew_point          -0.045139           0.071725             0.873965
# arrival_humidity           -0.021996           0.034098             0.672566
# arrival_pressure           -0.028774           0.041082             0.767296
# arrival_visibility          0.029932          -0.042865            -0.778566
#
#                      arrival_dew_point  arrival_humidity  arrival_pressure  \
# flight                        0.033313         -0.076056         -0.037467
# departure_delay               0.009512          0.007352          0.015086
# arrival_delay                 0.015613          0.010704          0.018920
# duration_expect              -0.224191         -0.210991         -0.237170
# duration                     -0.236312         -0.222904         -0.251043
# duration_delta                0.010137          0.005178          0.004592
# destiny.state                      NaN               NaN               NaN
# depart_temperature           -0.169880         -0.066508         -0.092739
# depart_dew_point             -0.228400         -0.139276         -0.160122
# depart_humidity              -0.078457         -0.091696         -0.085165
# depart_pressure              -0.045139         -0.021996         -0.028774
# depart_visibility             0.071725          0.034098          0.041082
# arrival_temperature           0.873965          0.672566          0.767296
# arrival_dew_point             1.000000          0.704850          0.572122
# arrival_humidity              0.704850          1.000000          0.885155
# arrival_pressure              0.572122          0.885155          1.000000
# arrival_visibility           -0.593182         -0.894102         -0.999684
#
#                      arrival_visibility
# flight                         0.026680
# departure_delay               -0.015420
# arrival_delay                 -0.019531
# duration_expect                0.239495
# duration                       0.253446
# duration_delta                -0.005055
# destiny.state                       NaN
# depart_temperature             0.103309
# depart_dew_point               0.167167
# depart_humidity                0.080896
# depart_pressure                0.029932
# depart_visibility             -0.042865
# arrival_temperature           -0.778566
# arrival_dew_point             -0.593182
# arrival_humidity              -0.894102
# arrival_pressure              -0.999684
# arrival_visibility             1.000000

# %% [markdown]
# Nos resultados acima, apresenta-se a correlação (porém, não a causalidade) entre as variáveis:<BR><BR>
# departure_delay e arrival_delay = 0,88<BR>
# arrival_dew_point e arrival_temperature = 0,87<BR>
# arrival_pressure e arrival_humidity = 0,88<BR><BR>
#
# Pelo lado da anti-correlação ou correlação negativa, tem-se:<BR><BR>
#
# arrival_visibility e arrival_pressure = -0,99<BR>
# depart_visibility e depart_pressure = -0,96<BR>
# arrival_visibility e arrival_humidity = -0,89<BR>
# arrival_visibility e arrival_temperature = -0,77<BR><BR>
#
# Seja c a variável de correlação estudada, registra-se que as outras correlações(positivas e negativas)
# encontra-se no intervalo [-0,76 <= c <= 0,76].<BR><BR>
#
# Portanto, as características que se encontram no intervalo de correlação acima, não serão estudadas.

# %% [markdown]
# A realização da estatítica descritiva permite um melhor entendimento dos dados e análise das correlações entre os atributos.<br><br>
# Com a utilização dos recursos gráficos para visualização dessas e outras medidas que se fizerem relevantes para o estudo e construindo-se uma matriz de correlação por meio do coeficiente de Pearson para todos os atributos do dataset dos voos domésticos, verifica-se que com exceção do relaciomento entre as variáveis acima já mencionadas, não identifica-se nenhuma outra correlação forte (próximo ou igual a 1). Portanto, padrões de atrasos seriam dificilmente descobertos por meio de uma análise de estatística descritiva.<br><br>
# Neste contexto, vislumbra-se a necessidade de revelar padrões escondidos nos dados e a utilização de processos de mineração de dados, tais como: regras de associação.

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
ax.set_title("Correlation matrix considering the Pearson coefficient between all the attributes of the Brazilian flight dataset", fontweight="bold", size=15)
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

# %% [markdown]
# Ainda no contexto da utilização dos recursos gráficos, pode-se obter o seguinte:<BR>
# A) uma rápida contabilização dos voos atrasados por ano e;
#
# B) plotagem de dois gráficos: visulização ao longo do tempo e percentual dos atrasos por ano.

# %%
df["arrival_expect_date"] = pd.to_datetime(df["arrival_expect_date"], format="%d/%m/%Y")
df["arrival_expect_hour"] = pd.to_datetime(df["arrival_expect_hour"], format="%H:%M:%S")

df["depart_expect_date"] = pd.to_datetime(df["depart_expect_date"], format="%d/%m/%Y")
df["depart_expect_hour"] = pd.to_datetime(df["depart_expect_hour"], format="%H:%M:%S")

df["depart_expect"] = pd.to_datetime(df["depart_expect"], format="%d/%m/%Y %H:%M")
df["depart"] = pd.to_datetime(df["depart"], format="%d/%m/%Y %H:%M")

df["arrival_expect"] = pd.to_datetime(df["arrival_expect"], format="%d/%m/%Y %H:%M")
df["arrival"] = pd.to_datetime(df["arrival"], format="%d/%m/%Y %H:%M")

df['year'] = df['depart'].dt.year # Adiciona coluna ano
grouped = df.groupby(['year'], as_index=False).flight.count() # Contabiliza total de voos atrasados agrupado por ano
grouped.plot(style='k--', label='Delayed Flights', x='year',y='flight', rot=20)

# %%
grouped.plot.pie(x='year',y='flight', autopct='%.2f%%', fontsize=12, figsize=(5, 5), title='% Delayed Flights per Year', textprops=dict(color="w"))
plt.legend(grouped['year'], title="Years", loc="right", bbox_to_anchor=(1, 0, 0.2, 1))

# %% [markdown]
# Verifica-se pelos gráficos acima em relação aos atrasos dos voos:<br><br>
#
# A) aumento de 2009 até 2010; <br><br>
# B) declínio acentuado de 2010 até 2012; <br><br>
# C) oscilação entre os anos de 2012 até 2015; e<br><br>
# D) outro declínio acentuado de 2015 até 2017;

# %% [markdown]
# Com as análises acima realizadas, permite-se executar:<BR><BR>
# Transformação de valores por meio do uso da média ou desvio-padrão;<BR>
# Seleção de dados e atributos por meio do uso de medidas de correlação;

# %% [markdown]
# #### 2. Análise de Frequência

# %% [markdown]
# Considerando-se apenas os voos domésticos, pode-se verificar a frequência das partidas dos principais aeroportos (cuja representatividade é de algo em torno de 80% do total dos voos).

# %%
# Group by variable ORIGIN and count the number of destiny
grouped = df.groupby(['origin'], as_index=False).destiny.count()

df_origin = pd.DataFrame(grouped)

# Define a list of international (INTL) airports-origin to be dropped
intl_origins = ['KJFK','MPTO','SAEZ','SCEL','SKBO','SPJC','SUMU']

# Create a new dataframe dropping the international airports
df_origin_new = df_origin[~df_origin.isin(intl_origins)].dropna()

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(aspect="equal"))

data = df_origin_new['destiny']
origins = df_origin_new['origin']

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.2f}%\n({:d} flights)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, origins,
          title="Origin",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Departure Flights Concentration")

plt.show()

# %% [markdown]
# Análise dos atrasos nas chegadas por meio de histograma e densidade:

# %%
# removendo os valores de atrasos acima de 24h nas partidas e chegadas
df = df.query('~(arrival_delay > 1440)') 
df = df.query('~(departure_delay > 1440)')

# removendo os valores NaN de atrasos nas partidas e chegadas
df = df.dropna(subset=['arrival_delay'])
df = df.dropna(subset=['departure_delay'])

# %%
df['departure_delay'].describe()
# Out:
# count    69424.000000
# mean        16.787221
# std         95.465045
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1438.000000
# Name: departure_delay, dtype: float64

# %%
df['arrival_delay'].describe()
# Out:
# count    69424.000000
# mean        17.111028
# std         96.572879
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1439.000000
# Name: arrival_delay, dtype: float64

# %%
# a faixa de valores dos atrasos nas chegadas está entre 0 e 1439 minutos (max)
# definindo-se a largura do bin = 17 minutos de atraso nas chegadas (média)
# poderíamos ter a quantidade de bins definida por [max - min] / mean = (1439/17)

plt.figure(figsize=(10,6))

plt.hist(df['arrival_delay'], color = 'blue', edgecolor = 'black',
         bins = int(df['arrival_delay'].max()/df['arrival_delay'].mean()))

plt.xlim(0,240)

plt.title('Histogram of Arrival Delays')
plt.xlabel('Delay (min)'); plt.ylabel('Flights');

# %% [markdown]
# Análise dos atrasos nas chegadas (por companhia aérea) usando-se histograma e densidade:

# %%
# Make a separate list for each airline
x1 = list(df[df['airline'] == 'TAM']['arrival_delay'])
x2 = list(df[df['airline'] == 'TAP']['arrival_delay'])
x3 = list(df[df['airline'] == 'AAL']['arrival_delay'])

# Assign colors for each airline and the names
colors = ['red', 'black', 'blue']
names = ['TAM', 'TAP', 'AAL']

plt.figure(figsize=(10,6))

plt.xlim(0,240)
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3], bins=int(df['arrival_delay'].max()/df['arrival_delay'].mean()),
         normed=True, color=colors, label=names)

# Plot formatting
plt.legend()
plt.xlabel('Delay (min)')

plt.ylabel('Normalized Flights')
plt.title('Side-by-Side Histogram with Multiple Airlines')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# Text(0.5,1,'Side-by-Side Histogram with Multiple Airlines')

# %%
plt.figure(figsize=(10,6))

plt.xlim(0,240)

# aqui usando seaborn

sns.distplot(df['arrival_delay'], hist = False, kde = True,
                 kde_kws = {'shade': True, 'linewidth': 3})

# %%
plt.figure(figsize=(10,6))

plt.xlim(0,240)

airlines = ['TAM', 'TAP', 'AAL']

for airline in airlines:

    subset = df[df['airline'] == airline]
    
    sns.distplot(subset['arrival_delay'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = airline)
    
plt.legend(prop={'size': 12}, title = 'Airline')
plt.title('Density Plot with Multiple Airlines'); 
plt.xlabel('Delay (min)')
plt.ylabel('Density');

# %% [markdown]
# **Remoção de outliers**.<br><br>
#
# Cerca de 68% dos valores de uma distribuição normal estão a um σ (desvio-padrão) da média; cerca de 95% estão a dois sigmas; e 99.7% estão a 3 sigmas.<br><br>

# %% [markdown]
# <img src="outliers.png">

# %%
# Procurando por outliers por meio do gráfico boxplot
#
plt.subplots(figsize=(10, 10))
df.boxplot(rot=45)

# %% [markdown]
# Analisando-se o gráfico acima, pode-se observar que as variáveis **departure_delay**, **arrival_delay**, **duration_expect**, **duration** e **duration_delta** possuem outliers.<br><br>
# As demais não possuem outliers.

# %%
#------------------------------------------------------------------------------
# accept a dataframe, remove outliers, return cleaned data in a new dataframe
# see http://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm
#------------------------------------------------------------------------------
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
remove_outlier(df, 'departure_delay')
# Out:
# Empty DataFrame
# Columns: [destiny, arrival_expect_date, arrival_expect_hour, origin, depart_expect_date, depart_expect_hour, airline, flight, line_type, depart_expect, depart, arrival_expect, arrival, status, observation, departure_delay, arrival_delay, duration_expect, duration, duration_delta, origin.state, destiny.state, depart_temperature, depart_dew_point, depart_humidity, depart_pressure, depart_visibility, depart_conditions, arrival_temperature, arrival_dew_point, arrival_humidity, arrival_pressure, arrival_visibility, arrival_conditions, year]
# Index: []
#
# [0 rows x 35 columns]

# %%
remove_outlier(df, 'arrival_delay')
# Out:
# Empty DataFrame
# Columns: [destiny, arrival_expect_date, arrival_expect_hour, origin, depart_expect_date, depart_expect_hour, airline, flight, line_type, depart_expect, depart, arrival_expect, arrival, status, observation, departure_delay, arrival_delay, duration_expect, duration, duration_delta, origin.state, destiny.state, depart_temperature, depart_dew_point, depart_humidity, depart_pressure, depart_visibility, depart_conditions, arrival_temperature, arrival_dew_point, arrival_humidity, arrival_pressure, arrival_visibility, arrival_conditions, year]
# Index: []
#
# [0 rows x 35 columns]

# %%
remove_outlier(df, 'duration_expect')
# Out:
#       destiny arrival_expect_date arrival_expect_hour origin  \
# 0        KJFK          2009-01-01 1900-01-01 18:00:00   SBGR
# 1        KJFK          2009-01-02 1900-01-01 08:00:00   SBGR
# 2        KJFK          2009-01-02 1900-01-01 09:00:00   SBGL
# 3        KJFK          2009-01-02 1900-01-01 09:00:00   SAEZ
# 4        KJFK          2009-01-02 1900-01-01 09:00:00   SBGR
# 6        KJFK          2009-01-02 1900-01-01 09:00:00   SBGR
# 7        KJFK          2009-01-02 1900-01-01 09:00:00   SBGR
# 8        KJFK          2009-01-02 1900-01-01 18:00:00   SBGR
# 9        KJFK          2009-01-03 1900-01-01 08:00:00   SBGR
# 10       KJFK          2009-01-03 1900-01-01 09:00:00   SBGR
# 11       KJFK          2009-01-03 1900-01-01 09:00:00   SBGR
# 12       KJFK          2009-01-03 1900-01-01 09:00:00   SBGR
# 24           Light Rain                 7.2               3.5
# 25        Light Drizzle                 7.2               3.5
# 26             Overcast                 4.4               1.7
# 27        Mostly Cloudy                 1.1               1.8
# 28        Mostly Cloudy                 1.1               1.8
# 29        Mostly Cloudy                 1.1               1.8
# 30        Mostly Cloudy                 1.1               1.8
# ...                 ...                 ...               ...
# 82792             Clear                18.0              13.0
# 82793  Scattered Clouds                18.0              13.0
# 82794          Overcast                19.0              14.0
# 82795  Scattered Clouds                18.0              14.0
# 82796  Scattered Clouds                18.0              14.0
# 82797             Clear                18.0              14.0
# 82798             Clear                18.0              14.0
# 82799             Clear                18.0              14.0
# 82800  Scattered Clouds                17.0              15.0
# 82801              Haze                17.0              15.0
# 82802              Mist                19.0              15.0
# 82803     Mostly Cloudy                19.0              16.0
# 82804        Light Rain                19.0              16.0
# 82805             Clear                19.0              16.0
# 82806             Clear                19.0              16.0
# 82807             Clear                19.0              16.0
# 82808     Mostly Cloudy                18.0              17.0
# 82809             Clear                20.0              17.0
# 82810              Rain                20.0              18.0
# 82811  Scattered Clouds                20.0              18.0
# 82812             Clear                20.0              18.0
# 82813  Scattered Clouds                20.0              18.0
# 82814             Clear                20.0              18.0
# 82815  Scattered Clouds                20.0              18.0
# 82816             Clear                20.0              18.0
# 82817        Light Rain                19.0              17.0
# 82818             Clear                18.0              14.0
# 82819             Clear                18.0              14.0
# 82820     Mostly Cloudy                17.0              12.0
# 82821     Mostly Cloudy                17.0              12.0
#
#        arrival_humidity  arrival_pressure  arrival_visibility  \
# 0                  17.2              36.0              1025.4
# 1                   8.3              48.0              1016.0
# 2                   8.9              44.0              1015.1
# 3                   8.9              44.0              1015.1
# 4                   8.9              44.0              1015.1
# 6                   8.9              44.0              1015.1
# 7                   8.9              44.0              1015.1
# 8                   3.9              79.0              1008.5
# 9                  10.0              44.0              1015.7
# 10                  9.4              43.0              1015.7
# 11                  9.4              43.0              1015.7
# 12                  9.4              43.0              1015.7
# 13                 10.6              33.0              1015.7
# 14                 11.1              40.0              1017.9
# 15                 12.2              43.0              1019.7
# 16                 12.2              40.0              1019.7
# 17                 12.2              40.0              1019.7
# 18                 12.2              40.0              1019.7
# 19                 12.2              40.0              1019.7
# 20                 12.2              40.0              1019.7
# 21                 10.6              36.0              1017.8
# 22                  2.8              55.0              1014.3
# 23                  1.7              53.0              1014.9
# 24                  1.7              53.0              1014.9
# 25                  1.7              53.0              1014.9
# 26                  3.3              58.0              1015.1
# 27                 14.4              31.0              1018.8
# 28                 14.4              31.0              1019.4
# 29                 14.4              31.0              1019.4
# 30                 14.4              31.0              1019.4
# ...                 ...               ...                 ...
# 82792              73.0            1020.0                 NaN
# 82793              73.0            1020.0                 NaN
# 82794              73.0            1020.0                10.0
# 82795              77.0            1020.0                10.0
# 82796              77.0            1020.0                10.0
# 82797              82.0            1020.0                10.0
# 82798              82.0            1020.0                10.0
# 82799              82.0            1020.0                10.0
# 82800              88.0            1019.0                10.0
# 82801              88.0            1019.0                10.0
# 8            Light Rain                 0.6               4.3
# 9      Scattered Clouds                 1.1               3.9
# 10        Mostly Cloudy                 2.2               2.7
# 11        Mostly Cloudy                 2.2               2.7
# 12        Mostly Cloudy                 2.2               2.7
# 14        Mostly Cloudy                 1.1               4.8
# 15     Scattered Clouds                 1.1               6.9
# 16                Clear                 0.0               6.0
# 18                Clear                 0.0               6.0
# 19        Mostly Cloudy                 0.0               6.0
# 20        Mostly Cloudy                 0.0               6.0
# 21             Overcast                 3.3               0.6
# 22           Light Rain                 5.6               2.8
# 23        Light Drizzle                 7.2               3.5
# 24           Light Rain                 7.2               3.5
# 25        Light Drizzle                 7.2               3.5
# 26             Overcast                 4.4               1.7
# 27        Mostly Cloudy                 1.1               1.8
# 28        Mostly Cloudy                 1.1               1.8
# 29        Mostly Cloudy                 1.1               1.8
# 30        Mostly Cloudy                 1.1               1.8
# 31        Mostly Cloudy                 1.1               1.8
# 32     Scattered Clouds                 1.1               1.8
# ...                 ...                 ...               ...
# 82792             Clear                18.0              13.0
# 82793  Scattered Clouds                18.0              13.0
# 82794          Overcast                19.0              14.0
# 82795  Scattered Clouds                18.0              14.0
# 82796  Scattered Clouds                18.0              14.0
# 82797             Clear                18.0              14.0
# 82798             Clear                18.0              14.0
# 82799             Clear                18.0              14.0
# 82800  Scattered Clouds                17.0              15.0
# 82801              Haze                17.0              15.0
# 82802              Mist                19.0              15.0
# 82803     Mostly Cloudy                19.0              16.0
# 82804        Light Rain                19.0              16.0
# 82805             Clear                19.0              16.0
# 82806             Clear                19.0              16.0
# 82807             Clear                19.0              16.0
# 82808     Mostly Cloudy                18.0              17.0
# 82809             Clear                20.0              17.0
# 82810              Rain                20.0              18.0
# 82811  Scattered Clouds                20.0              18.0
# 82812             Clear                20.0              18.0
# 82813  Scattered Clouds                20.0              18.0
# 82814             Clear                20.0              18.0
# 82815  Scattered Clouds                20.0              18.0
# 82816             Clear                20.0              18.0
# 82817        Light Rain                19.0              17.0
# 82818             Clear                18.0              14.0
# 82819             Clear                18.0              14.0
# 82820     Mostly Cloudy                17.0              12.0
# 82821     Mostly Cloudy                17.0              12.0
#
#        arrival_humidity  arrival_pressure  arrival_visibility  \
# 0                  17.2              36.0              1025.4
# 1                   8.3              48.0              1016.0
# 2                   8.9              44.0              1015.1
# 3                   8.9              44.0              1015.1
# 4                   8.9              44.0              1015.1
# 6                   8.9              44.0              1015.1
# 7                   8.9              44.0              1015.1
# 8                   3.9              79.0              1008.5
# 9                  10.0              44.0              1015.7
# 10                  9.4              43.0              1015.7
# 11                  9.4              43.0              1015.7
# 12                  9.4              43.0              1015.7
# 14                 11.1              40.0              1017.9
# 15                 12.2              43.0              1019.7
# 16                 12.2              40.0              1019.7
# 18                 12.2              40.0              1019.7
# 19                 12.2              40.0              1019.7
# 20                 12.2              40.0              1019.7
# 21                 10.6              36.0              1017.8
# 22                  2.8              55.0              1014.3
# 23                  1.7              53.0              1014.9
# 24                  1.7              53.0              1014.9
# 25                  1.7              53.0              1014.9
# 82812       Mostly Cloudy  2011.0
# 82813       Mostly Cloudy  2011.0
# 82814       Mostly Cloudy  2011.0
# 82815    Scattered Clouds  2011.0
# 82816    Scattered Clouds  2011.0
# 82817       Mostly Cloudy  2011.0
# 82818    Scattered Clouds  2011.0
# 82819    Scattered Clouds  2011.0
# 82820       Partly Cloudy  2011.0
# 82821       Partly Cloudy  2011.0
#
# [61132 rows x 35 columns]

# %%
remove_outlier(df, 'duration_delta')
# Out:
# Empty DataFrame
# Columns: [destiny, arrival_expect_date, arrival_expect_hour, origin, depart_expect_date, depart_expect_hour, airline, flight, line_type, depart_expect, depart, arrival_expect, arrival, status, observation, departure_delay, arrival_delay, duration_expect, duration, duration_delta, origin.state, destiny.state, depart_temperature, depart_dew_point, depart_humidity, depart_pressure, depart_visibility, depart_conditions, arrival_temperature, arrival_dew_point, arrival_humidity, arrival_pressure, arrival_visibility, arrival_conditions, year]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# #### 3. Identificação de valores numéricos e categóricos

# %% [markdown]
# Dados categóricos são aqueles classificados de acordo com alguma categoria. Por exemplo, sexo: pode ser masculino ou feminino.<BR>
# A categoria dos dados podem ser: nominais ou ordinais. Nominais quando ocorre o exemplo mencionado e ordinais, quando ocorrem situações do tipo: escolaridade: 1o, 2o ou 3o grau.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76316 entries, 0 to 82821
# Data columns (total 35 columns):
# destiny                76316 non-null object
# arrival_expect_date    76316 non-null datetime64[ns]
# arrival_expect_hour    76316 non-null datetime64[ns]
# origin                 76316 non-null object
# depart_expect_date     76316 non-null datetime64[ns]
# depart_expect_hour     76316 non-null datetime64[ns]
# airline                76316 non-null object
# flight                 76316 non-null int64
# line_type              76314 non-null object
# depart_expect          76316 non-null datetime64[ns]
# depart                 69584 non-null datetime64[ns]
# arrival_expect         76316 non-null datetime64[ns]
# arrival                69584 non-null datetime64[ns]
# status                 76316 non-null object
# observation            16289 non-null object
# departure_delay        69584 non-null float64
# arrival_delay          69584 non-null float64
# duration_expect        76316 non-null int64
# duration               69584 non-null float64
# duration_delta         69584 non-null float64
# origin.state           56535 non-null object
# destiny.state          0 non-null float64
# depart_temperature     75950 non-null float64
# depart_dew_point       75501 non-null float64
# depart_humidity        75967 non-null float64
# depart_pressure        71527 non-null float64
# depart_visibility      49998 non-null float64
# depart_conditions      76316 non-null object
# arrival_temperature    76082 non-null float64
# arrival_dew_point      72851 non-null float64
# arrival_humidity       76079 non-null float64
# arrival_pressure       76128 non-null float64
# arrival_visibility     73794 non-null float64
# arrival_conditions     67230 non-null object
# year                   69584 non-null float64
# dtypes: datetime64[ns](8), float64(16), int64(2), object(9)
# memory usage: 21.0+ MB

# %% [markdown]
# Observando-se acima, temos as variáveis numéricas: **flight**, **duration_expect**, **departure_delay**, **arrival_delay**, **duration**, **duration_delta**, **destiny.state**, **depart_temperature**, **depart_dew_point**, **depart_humidity**, **depart_pressure**, **depart_visibility**, **arrival_temperature**, **arrival_dew_point**, **arrival_humidity**, **arrival_pressure**, **arrival_visibility** e **year**

# %% [markdown]
# Essas observações são importantes, pois ao aplicar-se algoritmos de machine learning e/ou data mining, pode-se ser necessário converter as variáveis numéricas em categóricas ou vice-versa.

# %% [markdown]
# #### 4. Análise, comparação de resultados e conclusão.

# %% [markdown]
# Uma vez tendo-se eliminado os outliers, pode-se verificar novamente a concentração dos voos e possíveis atrasos e propagações, por meio de um **mapa de calor**.

# %%
# Biblioteca de Mapas
import folium
# Cria um dataframe com as latitudes dos aeroportos (fonte: ANAC)
lat = pd.DataFrame({'lat': [0,0,0,-1.4,-15.87,-19.62,-3.03,-3.77,-22.8,-23.44,-23,-29.99,-8.12,-12.91]})
# Cria um dataframe com as longitudes dos aeroportos (fonte: ANAC)
long = pd.DataFrame({'long': [0,0,0,-48.45,-47.92,-43.97,-60.04,-38.52,-43.25,-46.47,-47.13,-51.17,-34.92,-38.33]})
# Junta os dataframes
dat1 = df_origin_new
dat2 = dat1.join(lat)
dat3 = dat2.join(long)
from folium import plugins
coordenadas = []
lat = dat3['lat'][:11].values
long = dat3['long'][:11].values

mapa = folium.Map(location=[-15.788497,-47.879873],tiles='Stamen Toner',zoom_start=3,width=450,height=330)

for la,lo in zip(lat,long):
    coordenadas.append([la,lo])

mapa.add_child(plugins.HeatMap(coordenadas))
mapa

# %% [markdown]
# <img src="Flight_Delay_Heat_Map.jpg">

# %% [markdown]
# Observa-se acima, que a região sudeste é a que mais concentra partidas com maior probabilidade de atrasos e propagações de atrasos para outras regiões do país.

# %% [markdown]
# Verifica-se pelas análises acima executadas que os atrasos dos voos domésticos estão dentro dos padrões esperados pela ANAC, seja por razões climatológicas estáveis do nosso país ou por melhorias operacionais no setor.<BR><BR>

# %% [markdown]
# Considerando-se a correlações verificadas, temos aqui uma questão interessante para ser avaliada.

# %% [markdown]
# Pode-se rotular as variáveis de interesse por meio de uma distribuição e a partir daí, inferir-se utilizando-se
# funções de mineração de dados, tais como: regras de associação e mineração de sequência de padrões,
# para estudar-se os fatores e os respectivos impactos de atrasos nas partidas e chegadas.

# %% [markdown]
# Porém, para manter-se o escopo deste trabalho, reforça-se apenas a título de exemplo, a correlação entre essas variáveis e a possibilidade de predição de atraso nas chegadas em função do atraso na partida do voo.

# %% [markdown]
# **Teste do P-value**

# %%
import statsmodels.api as sm
from scipy import stats

X = df.departure_delay
y = df.arrival_delay

X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
print("P-value entre as variáveis departure_delay e arrival_delay = %1.2f" % est.fit().f_pvalue)
# Out:
# P-value entre as variáveis departure_delay e arrival_delay = 0.00

# %% [markdown]
# Ou seja com o valor de P-value calculado acima < 0.05, temos que a correlação entre as variáveis é significativa.

# %% [markdown]
# **Análise dos Resíduos**

# %% [markdown]
# Cálculo do array de resíduos

# %%
import statsmodels.formula.api as sm

# cria um dataframe com os resultados de X e y
X_df = pd.DataFrame(X)
y_df = pd.DataFrame(y)
dat_df = X_df.join(y_df)

results = sm.ols(formula='y ~ X', data=dat_df).fit()
Y_pred = results.predict(dat_df[["arrival_delay"]])
residual = dat_df["arrival_delay"].values-Y_pred
residual
# Out:
# 0        -0.407957
# 1        -0.407957
# 2        28.822629
# 3        -0.407957
# 4        -0.407957
# 6        -0.407957
# 7        -0.407957
# 8        46.702323
# 9        44.158482
# 10       -0.407957
# 11       -0.407957
# 12       29.792552
# 14       32.792552
# 15       22.732399
# 16       -0.407957
# 18       -0.407957
# 19       46.842680
# 20       -0.032002
# 21       24.812603
# 22       14.802578
# 23       41.459246
# 24       69.837667
# 25       -0.407957
# 26       28.697310
# 27       -0.407957
# 28       -0.407957
# 29       -0.407957
# 30       -0.407957
# 31       -0.407957
# 32       -0.407957
#            ...
# 82792    -0.407957
# 82793    -0.407957
# 82794    -0.407957
# 82795    -0.407957
# 82796    -0.407957
# 82797    14.762476
# 82798    -0.407957
# 82799    -2.187397
# 82800     2.629679
# 82801    -0.407957
# 82802    -0.407957
# 82803    -0.407957
# 82804    -0.407957
# 82805    -0.407957
# 82806    -0.407957
# 82807   -13.104645
# 82808    -0.407957
# 82809    -0.407957
# 82810    -0.407957
# 82811    -0.407957
# 82812   -20.187397
# 82813    -0.407957
# 82814    -0.407957
# 82815    -0.407957
# 82816    -8.367855
# 82817    -0.407957
# 82818    -0.407957
# 82819   -18.112206
# 82820    -0.407957
# 82821    -0.407957
# Length: 69424, dtype: float64

# %% [markdown]
# Os resíduos aumentam muito pouco com o crescimento dos atrasos nas partidas.

# %%
dat_df["departure_delay"].describe()
# Out:
# count    69424.000000
# mean        16.787221
# std         95.465045
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1438.000000
# Name: departure_delay, dtype: float64

# %%
dat_df["arrival_delay"].describe()
# Out:
# count    69424.000000
# mean        17.111028
# std         96.572879
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       1439.000000
# Name: arrival_delay, dtype: float64

# %%
Y_pred.describe()
# Out:
# count    69424.000000
# mean        17.111028
# std         94.986503
# min          0.407957
# 25%          0.407957
# 50%          0.407957
# 75%          0.407957
# max       1431.199640
# dtype: float64

# %% [markdown]
# Cálculo do coeficiente de determinação (R$^2$)

# %%
from scipy.stats import chisquare
chisquare(dat_df["arrival_delay"],Y_pred)
# Out:
# Power_divergenceResult(statistic=3032246.3955383818, pvalue=0.0)

# %% [markdown]
# Exibindo gráfico da regressão linear

# %%
plt.scatter(dat_df["departure_delay"], dat_df["arrival_delay"],color='b')
plt.plot(dat_df["departure_delay"], Y_pred, color='red', linewidth=3)
plt.show()

# %% [markdown]
# Tão importante quanto fazer a regressão linear simples é saber se o resultado obtido é coerente. Afinal, se não existir uma correlação entre as variáveis, não faz sentido utilizar essa ferramenta estatística. No exemplo, todos os critérios foram atendidos, logo, é possível utilizar a regressão linear simples para estudar o seu processo de predição dos atrasos nas chegadas com base nas partidas. Porém, muitas vezes a regressão linear não é um bom modelo, e torna-se necessário utilizar outras ferramentas.

# %% [markdown]
# Não obstante, a aplicação de algoritmos de predição para os atrasos podem-se tornar ferramentas importantes não somente pelo fato da constatação do atraso em si, mas pela comunicação prévia aos usuários do transporte aéreo e remanejos de operações que sejam úteis a mitigação da propagação desses atrasos.
